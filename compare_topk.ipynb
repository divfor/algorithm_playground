# %%
import numpy as np
import pandas as pd
import os
from binascii import hexlify

# %%
def topk(filename="bn.npy", k=100000):
    d = np.load(filename)
    d = d[d['n-gram'] != b'']
    d = pd.DataFrame(d)
    d['counter'] = abs(d['counter'])
    d.sort_values(by='counter',ascending=False, inplace=True)
    top = d.head(k)
    if top.duplicated('n-gram').any():
        print("duplicated found !!!")
    return top

# %%
topk1 = topk("bn.1m.npy", 100000) #topk_of_1m
s1 = set([i for i in topk1['n-gram']])
print("len(s1)=%ld" % len(s1))
topk1[topk1['counter'] > 100]
# Out:
# len(s1)=100000
#         counter     n-gram
# 63058     93565    b';q=0'
# 107971    93565    b'q=0.'
# 73702     74856    b'cept'
# 77446     74852    b'Acce'
# 9763      74852    b'ccep'
# 31992     60320    b'tion'
# 34395     56165    b'ache'
# 94747     56139    b'ept-'
# 44032     56139    b'xml,'
# 109283    56139    b'text'
# 55167     56139    b'=0.5'
# 76346     56139    b'ext/'
# 78510     56137    b'ost:'
# 72897     41650    b'lica'
# 108729    41606    b'atio'
# 102118    41592    b'plic'
# 55025     41590    b'icat'
# 110548    41588    b'cati'
# 91534     41588    b'appl'
# 108406    41586    b'ion/'
# 25423     41586    b'on/x'
# 82627     41586    b'ppli'
# 31857     37453    b'host'
# 101781    37443    b'8080'
# 26894     37437    b'lhos'
# 69305     37437    b'alho'
# 107604    37435    b'loca'
# 25297     37435    b'ocal'
# 92957     37434    b'late'
# 59110     37430    b'cach'
# ...         ...        ...
# 92102       106    b'ra&c'
# 76405       106  b'52\r\n'
# 73552       104    b'2C+5'
# 31824       104    b're=E'
# 32596       104    b'r&em'
# 92688       104    b'ador'
# 705         104    b't&dn'
# 21302       104    b'aste'
# 39883       104    b'l%40'
# 58114       104    b'ad=1'
# 10964       104    b'%40t'
# 57377       104    b'2C+3'
# 30585       104    b'era+'
# 68511       104    b'ana&'
# 5858        104    b'l&pa'
# 89823       104    b'rd=r'
# 31115       104    b'Sala'
# 26956       104    b'e&cp'
# 42025       104    b'ad=9'
# 86913       104    b'il=l'
# 107928      102    b'e&em'
# 63515       102    b're=G'
# 88729       102    b'ad=T'
# 4502        102    b'=Nav'
# 21353       102    b'lama'
# 74104       102    b'W&di'
# 18325       102  b'53\r\n'
# 30152       102    b'es&c'
# 114891      102    b'y%40'
# 54477       101  b'AD\r\n'
#
# [1356 rows x 2 columns]

# %%
topk2 = topk("bn.newest.npy", 100000) #topk_of_10k
s2 = set([i for i in topk2['n-gram']])
print("len(s2)=%ld" % len(s2))
print("len(s2.intersection(s1))=%ld" % len(s2.intersection(s1)))
topk2[topk2['counter'] > 100]
# Out:
# len(s2)=100000
# len(s2.intersection(s1))=95286
#         counter     n-gram
# 71105     93565    b';q=0'
# 51869     93565    b'q=0.'
# 2114      74856    b'cept'
# 20536     74852    b'Acce'
# 49111     74852    b'ccep'
# 38396     60320    b'tion'
# 50519     56165    b'ache'
# 98570     56139    b'xml,'
# 15222     56139    b'ext/'
# 32070     56139    b'=0.5'
# 58542     56139    b'text'
# 106148    56139    b'ept-'
# 25816     56137    b'ost:'
# 119761    41650    b'lica'
# 55732     41606    b'atio'
# 22440     41592    b'plic'
# 31278     41590    b'icat'
# 90308     41588    b'appl'
# 64949     41588    b'cati'
# 5783      41586    b'on/x'
# 54102     41586    b'ion/'
# 46334     41586    b'ppli'
# 37659     37453    b'host'
# 20724     37443    b'8080'
# 101763    37437    b'alho'
# 13085     37437    b'lhos'
# 50064     37435    b'loca'
# 5160      37435    b'ocal'
# 97595     37434    b'late'
# 51509     37430    b'cach'
# ...         ...        ...
# 688         106    b'elon'
# 8092        106    b'Nava'
# 42957       104    b'2C+3'
# 3460        104    b't&dn'
# 77918       104    b'l%40'
# 96316       104    b'ador'
# 29650       104    b'l&pa'
# 67630       104    b'il=l'
# 13393       104    b'e&cp'
# 55094       104    b'%40t'
# 46637       104    b'ad=1'
# 88580       104    b'ad=9'
# 1411        104    b'2C+5'
# 37491       104    b're=E'
# 41403       104    b'r&em'
# 97925       104    b'ana&'
# 31093       104    b'era+'
# 33796       104    b'Sala'
# 81768       104    b'rd=r'
# 107505      104    b'aste'
# 22907       102    b'=Nav'
# 76375       102    b'ad=T'
# 4080        102    b'W&di'
# 29042       102    b'es&c'
# 87059       102    b'y%40'
# 92517       102  b'53\r\n'
# 73467       102    b're=G'
# 51621       102    b'e&em'
# 107705      102    b'lama'
# 28506       101  b'AD\r\n'
#
# [1356 rows x 2 columns]

# %%
len(s1.intersection(s2))
# Out:
# 9783

# %%
s1.loc[s1.index.difference(s2.index)]
# Out:
# 8         b'340&'
# 13        b'9973'
# 41        b'o+S%'
# 51        b'asia'
# 54        b'n%E9'
# 57        b'6824'
# 61        b'a+Se'
# 87        b're=O'
# 113       b'jpg '
# 123       b'=361'
# 141       b'0427'
# 150       b'FF&c'
# 158       b'rlos'
# 159       b'264F'
# 166       b'AF35'
# 176       b'ras&'
# 182       b'6025'
# 186       b'6924'
# 196       b'7606'
# 199       b'C17E'
# 234       b'112&'
# 237       b'ana+'
# 255       b'B893'
# 285       b'3244'
# 289       b'as.j'
# 291       b'51&B'
# 302       b'140&'
# 315       b'8795'
# 322       b'-gzi'
# 324       b'el&a'
#            ...
# 121438    b'4921'
# 121450    b'5, *'
# 121490    b'hero'
# 121507    b'tc=8'
# 121508    b'7479'
# 121513    b'adri'
# 121514    b'3%2C'
# 121522    b'7386'
# 121526    b'C+S%'
# 121549    b'n=Pa'
# 121550    b'2814'
# 121554    b'cos&'
# 121597    b'c=42'
# 121604    b'%28I'
# 121609    b'so+M'
# 121623    b'439F'
# 121626    b'1084'
# 121637    b'4928'
# 121649    b'lla&'
# 121658    b'40vi'
# 121663    b'5CA7'
# 121665    b'7963'
# 121688    b'8094'
# 121698    b'inco'
# 121739    b'dir+'
# 121769    b'6038'
# 121789    b'an%E'
# 121810    b'8924'
# 121811    b'0643'
# 121823    b'22FA'
# Name: n-gram, Length: 9184, dtype: object

# %%
s1.loc[s1.index.intersection(s2.index)]
# Out:
# 34395     b'ache'
# 55167     b'=0.5'
# 55025     b'icat'
# 82627     b'ppli'
# 59110     b'cach'
# 45972     b'html'
# 82094     b'gzip'
# 22896     b'imag'
# 53903     b'quer'
# 9325      b'ible'
# 45481     b': te'
# 98538     b'da1/'
# 24046     b'-Enc'
# 30483     b'e/pn'
# 89268     b'3.5.'
# 89156     b'ol: '
# 50643     b'ble;'
# 62265     b': x-'
# 78821    b'1.1\r'
# 33545     b't-La'
# 47457     b'.8,i'
# 42938     b', ut'
# 22836     b'p://'
# 59922     b'/xht'
# 38529     b'0 (c'
# 61628     b'TML/'
# 26301     b'xt/p'
# 63411     b'ain;'
# 97213     b'Conn'
# 96752     b'ion:'
#            ...
# 53347     b'5620'
# 81859     b'2245'
# 43335     b'8808'
# 32303     b'6225'
# 41542     b'DF83'
# 5091      b'B7AC'
# 5308      b'C2AE'
# 96883     b'2781'
# 72091     b'5A3A'
# 63800     b'E7AA'
# 77642     b'77D1'
# 22984     b'7741'
# 53223     b'9138'
# 61270     b'0943'
# 93034     b'E693'
# 81831     b'B4B4'
# 36148     b'3769'
# 36129     b'8272'
# 7056      b'D156'
# 79856     b'6580'
# 79934     b'0494'
# 97065     b'1386'
# 90948     b'6637'
# 93393     b'DA00'
# 57734     b'5587'
# 36256     b'9209'
# 80127     b'D721'
# 92619     b'ACF1'
# 28244     b'8D4E'
# 95739     b'9373'
# Name: n-gram, Length: 816, dtype: object

# %%
s2.loc[s2.index.difference(s1.index)]
# Out:
# 2         b'ruel'
# 12        b'i=81'
# 32        b'25F2'
# 34        b'i=60'
# 45        b'0343'
# 77        b't: l'
# 80        b'5313'
# 82        b'r%E9'
# 92        b'0345'
# 114       b'9491'
# 115       b'e=Br'
# 122       b'D=F2'
# 133       b'D=93'
# 138       b'9973'
# 139       b'edon'
# 148       b'4547'
# 151       b'N+&c'
# 162       b'0161'
# 164       b'AD30'
# 189       b'D=13'
# 198       b'eo&n'
# 210       b'o+Vi'
# 211       b'n=pe'
# 217       b'ara%'
# 220       b'911E'
# 221       b'9185'
# 231       b'+Esp'
# 250       b'e=Si'
# 271       b'40th'
# 274       b'SSIO'
#            ...
# 98655     b'ltra'
# 98677     b'1B22'
# 98692     b'=376'
# 98694     b'66&B'
# 98698     b'Manu'
# 98703     b'=177'
# 98706     b'7438'
# 98733     b'F32B'
# 98760     b'F97D'
# 98766     b'd&dn'
# 98798     b'1721'
# 98806     b'=371'
# 98819     b'D270'
# 98825     b'7612'
# 98834     b'isti'
# 98850     b'Mozi'
# 98855     b'8924'
# 98860     b'0184'
# 98861     b'xt/x'
# 98875     b'8CE3'
# 98881     b'Pe%F'
# 98889     b'7258'
# 98890     b'B572'
# 98929     b'c=36'
# 98938    b'248\r'
# 98955     b'22FA'
# 98956     b'defl'
# 98967     b'805D'
# 98972     b'=kar'
# 98978     b'trar'
# Name: n-gram, Length: 9184, dtype: object

# %%
s2.loc[s2.index.intersection(s1.index)]
# Out:
# 24539    b'ext/'
# 90304    b'atio'
# 61473    b'l,ap'
# 24046    b',app'
# 25925    b't:80'
# 30483    b'nque'
# 12429    b'agma'
# 41646    b'SION'
# 82892    b'ge: '
# 59784    b'er-A'
# 52197    b'gma:'
# 52735    b', ut'
# 73181    b'ml;q'
# 53527    b'or/3'
# 22166    b'ML/3'
# 36687    b'pt-L'
# 36555    b'g,*/'
# 38706    b'ge/p'
# 63619    b'l+xm'
# 38272    b'HTTP'
# 93810    b'TP/1'
# 95136    b'=0.8'
# 31435    b'-8;q'
# 33223    b'nux)'
# 96451    b'0.5,'
# 86584    b'ept:'
# 90893    b'ion:'
# 70016    b'on: '
# 95570    b'blic'
# 79027    b'gist'
#           ...
# 6189     b'2198'
# 81211    b'6612'
# 96977    b'776E'
# 6724     b'rd=G'
# 79414    b'00F1'
# 82794    b'38EC'
# 45481    b'D05C'
# 45203    b'BC99'
# 22096    b'8114'
# 88387    b'0F70'
# 96751    b'1761'
# 89504    b'7347'
# 91454    b'8D4E'
# 22984    b'3C56'
# 8552     b'79FA'
# 42067    b'1511'
# 42076    b'+Pen'
# 8399     b'6131'
# 41102    b'7915'
# 91389    b'74E8'
# 2549     b'BFF8'
# 86478    b'AD16'
# 42240    b'5835'
# 15427    b'71E6'
# 22896    b'7E5C'
# 56124    b'4189'
# 86215    b'C5AC'
# 40384    b'245D'
# 74343    b'0985'
# 409      b'ries'
# Name: n-gram, Length: 816, dtype: object
